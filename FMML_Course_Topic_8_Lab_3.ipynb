# %% [markdown]
# <a href="https://colab.research.google.com/github/NeerajMadhav/FMML_COURSE_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 17:41:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   103MB/s    in 0.7s
#
# 2023-05-04 17:41:32 (103 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21771   1309.1194v1  We describe ways to define and calculate $L_1$...  stat
# 16656  1704.08059v1  Skip-Gram Negative Sampling (SGNS) word embedd...    cs
# 5262    1208.2417v1  We examine a fundamental problem that models v...  stat
# 30537  1712.04927v1  Text spotting is an interesting research probl...    cs
# 36248  1604.05358v1  In this paper, we introduce new methods and di...    cs
# ...             ...                                                ...   ...
# 2146   1607.01036v4  In distributed, or privacy-preserving learning...  stat
# 5909    1212.6316v1  In some applications and in order to address r...  stat
# 9642   1612.05846v2  Diffusion MRI (dMRI) provides the ability to r...  stat
# 32768  1506.04557v4  We present doubly stochastic gradient MCMC, a ...    cs
# 6961   1708.02582v3  Injecting adversarial examples during training...  stat
#
#                                                    title  year  \
# 21771     Some Options for L1-Subspace Signal Processing  2013
# 16656  Riemannian Optimization for Skip-Gram Negative...  2017
# 5262   How to sample if you must: on optimal function...  2012
# 30537  Enhanced Characterness for Text Detection in t...  2017
# 36248  Text-based LSTM networks for Automatic Music C...  2016
# ...                                                  ...   ...
# 2146   Bootstrap Model Aggregation for Distributed St...  2016
# 5909       On-line relational SOM for dissimilarity data  2012
# 9642   Joint Spatial-Angular Sparse Coding for dMRI w...  2016
# 32768  Learning Deep Generative Models with Doubly St...  2015
# 6961   Cascade Adversarial Machine Learning Regulariz...  2017
#
#                                                 keywords
# 21771  [calculate, subspaces, sensitive, calculated, ...
# 16656  [embedding, implementation, optimized, stochas...
# 5262   [fundamental, tomography, multivariate, distri...
# 30537  [interesting, improving, detection, utilizing,...
# 36248  [introduce, automatic, composition, relationsh...
# ...                                                  ...
# 2146   [distributed, preserving, probabilistic, estim...
# 5909   [applications, situations, dissimilarities, or...
# 9642   [diffusion, reconstruct, measuring, diffusion,...
# 32768  [stochastic, inference, generative, collapsed,...
# 6961   [injecting, adversarial, adversarial, robustne...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21771    [calculate, subspaces, sensitive, calculated, ...
# 16656    [embedding, implementation, optimized, stochas...
# 5262     [fundamental, tomography, multivariate, distri...
# 30537    [interesting, improving, detection, utilizing,...
# 36248    [introduce, automatic, composition, relationsh...
#                                ...
# 872      [applicative, represented, numerical, techniqu...
# 22251    [introduce, multivariate, stochastic, volatili...
# 2771     [reinforcement, challenge, objective, physiolo...
# 2319     [opportunistic, independent, secondary, inform...
# 22719    [analyzing, underlying, structure, sequences, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8728 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e82a4b89-5a90-464c-a33b-c837896c4932" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e82a4b89-5a90-464c-a33b-c837896c4932")) {                    Plotly.newPlot(                        "e82a4b89-5a90-464c-a33b-c837896c4932",                        [{"x":["calculated","component","asymptotically","calculation","principal","engineering","calculate","algorithm","projection","estimation","evaluations","illustrations","reduction","direction","subspaces","generalize","containing","computation","sensitive","complexity","processing","components","dimension","dimensionality","optimization","searching","optimizes","embedding","riemannian","implementation","framework","superiority","competitors","demonstrates","stochastic","constraint","optimized","objective","addressed","expectation","solutions","functional","optimally","distribution","combinations","efficient","structured","multivariate","tomography","functionals","difficulty","estimated","fundamental","performance","improving","evaluation","comprehensive","combination","comparative","detection","maximally","rejecting","interesting","generalization","traditional","utilizing","represent","progressions","diversity","parameter","experiments","character","automatic","controlling","relationships","introduce","composition","documents","perspectives","designing","programming","computing","evolutionary","emphasize","researchers","advantage","computers","algorithms","application","important","henceforth","parallelism","representations","theoretical","considered","techniques","operators","including","chromosomes","randomness","information","dimensional","significant","simulation","enhancement","mechanisms","hyperacuity","dominance","biological","redundant","demonstration","environment","probabilistic","characteristics","advantages","heuristic","architecture","movements","specifies","binocular","correction","artificial","measurements","processes","redundancy","approaching","architectural","structural","representation","precision","filtering","annotations","clustering","challenging","classifying","segmentation","supervised","intermediate","significantly","localization","classification","recognition","curriculum","predictions","collected","instances","incorporate","counterparts","competitive","depending","translation","permutations","polynomial","synchronous","strategies","nonterminal","permutation","answering","interactively","conversation","understanding","extraction","interactive","motivated","introductory","collection","approaches","development","attention","expensive","illustrate","satisfies","consequences","condition","association","threefold","sufficient","necessary","formulates","equivalent","continuous","equivalence","practical","determining","establish","mathematical","metaheuristic","knowledge","combinatorial","similarity","disambiguation","relatedness","selection","exponential","estimates","simplification","applications","disambiguate","neighbors","distributional"],"y":[27,116,11,17,38,52,30,823,55,211,49,1,101,61,17,55,49,154,50,245,299,108,66,55,308,30,15,121,10,149,574,38,9,62,138,78,46,185,35,32,168,40,18,234,38,401,113,22,14,4,39,60,95,828,101,251,57,134,42,334,8,2,83,89,178,42,121,1,35,120,614,54,171,16,65,330,31,59,19,55,116,130,59,7,63,104,18,617,242,366,2,14,236,155,142,374,45,256,2,7,741,193,251,97,32,43,2,5,35,27,17,131,168,101,90,64,240,23,5,4,13,137,45,117,22,7,5,68,356,89,72,56,157,272,50,181,203,36,277,72,487,346,5,76,59,80,64,14,126,32,102,8,63,5,93,2,9,47,5,13,192,148,36,55,5,75,445,127,172,71,80,18,9,40,30,3,68,70,6,56,118,21,144,46,46,56,5,371,44,149,15,10,132,39,68,8,432,3,21,26],"type":"bar"},{"x":["calculated","component","asymptotically","calculation","principal","engine ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Caffe</span> <span style=''>con</span> <span style=''>Troll</span> <span style=''>Shallow</span> <span style=''>Ideas</span> <span style=''>to</span> <span style=''>Speed</span> <span style=''>Up</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>Caffe</span> <span style=''>con</span> <span style=''>Troll</span> <span style=''>(CcT)</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compatible</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>Caffe</span> <span style=''>with</span> <span style=''>rebuilt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>internals</span> <span style=''>We</span> <span style=''>built</span> <span style=''>CcT</span> <span style=''>to</span> <span style=''>examine</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.3648648648648648);'>characteristics</span> <span style=''>of</span> <span style=''>training</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>deploying</span> <span style=''>general</span> <span style=''>purpose</span> <span style='background-color:rgba(0, 255, 0, 0.6291666666666667);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.32437275985663083);'>different</span> <span style=''>hardware</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>employing</span> <span style=''>standard</span> <span style=''>batching</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>optimizations</span> <span style=''>for</span> <span style=''>CPU</span> <span style=''>training</span> <span style=''>we</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>45x</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3422222222222222);'>improvement</span> <span style=''>over</span> <span style=''>Caffe</span> <span style=''>on</span> <span style=''>popular</span> <span style=''>networks</span> <span style=''>like</span> <span style=''>CaffeNet</span> <span style=''>Moreover</span> <span style=''>with</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3950617283950617);'>improvements</span> <span style=''>the</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>training</span> <span style=''>time</span> <span style=''>for</span> <span style=''>CNNs</span> <span style=''>is</span> <span style=''>directly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proportional</span> <span style=''>to</span> <span style=''>the</span> <span style=''>FLOPS</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>delivered</span> <span style=''>by</span> <span style=''>the</span> <span style=''>CPU</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>train</span> <span style=''>hybrid</span> <span style=''>CPU</span> <span style=''>GPU</span> <span style=''>systems</span> <span style=''>for</span> <span style=''>CNNs</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Geometric</span> <span style=''>Mean</span> <span style=''>Metric</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>revisit</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>metric</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>approach</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>from</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>it</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>Indeed</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>even</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style=''>This</span> <span style=''>solution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>possesses</span> <span style=''>several</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>(i)</span> <span style=''>an</span> <span style=''>innate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style=''>appeal</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Riemannian</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>matrices</span> <span style=''>(ii)</span> <span style=''>ease</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>and</span> <span style=''>(iii)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>speed</span> <span style=''>several</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>magnitude</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>the</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>LMNN</span> <span style=''>and</span> <span style=''>ITML</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>on</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>our</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistently</span> <span style=''>attains</span> <span style=''>higher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>accuracy</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>EigenGP</span> <span style=''>Sparse</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>models</span> <span style=''>with</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenfunctions</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6402877697841727);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.32588454376163883);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>GP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>design</span> <span style='background-color:rgba(255, 0, 0, 0.75);'>nonstationary</span> <span style=''>GP</span> <span style=''>priors</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>model</span> <span style=''>EigenGP</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Karhunen</span> <span style=''>Loeve</span> <span style=''>(KL)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style=''>a</span> <span style=''>GP</span> <span style=''>prior</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>Nystrom</span> <span style='background-color:rgba(255, 0, 0, 0.33548387096774196);'>approximation</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenfunctions</span> <span style=''>and</span> <span style=''>select</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenfunctions</span> <span style=''>by</span> <span style=''>evidence</span> <span style='background-color:rgba(255, 0, 0, 0.38823529411764707);'>maximization</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenfunctions</span> <span style=''>in</span> <span style=''>our</span> <span style=''>model</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.75);'>nonstationary</span> <span style='background-color:rgba(255, 0, 0, 0.6204379562043796);'>covariance</span> <span style=''>function</span> <span style=''>To</span> <span style=''>handle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>likelihoods</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.41284 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Concept</span> <span style=''>Drift</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypothesis</span> <span style=''>Testing</span> <br/><br/><span style=''>In</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>there</span> <span style=''>is</span> <span style=''>often</span> <span style=''>a</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>and</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>concept</span> <span style=''>drifts</span> <span style=''>(ie</span> <span style=''>changes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>and</span> <span style=''>response</span> <span style=''>variables)</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>mitigate</span> <span style=''>deteriorating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>over</span> <span style=''>time</span> <span style=''>Various</span> <span style=''>concept</span> <span style=''>drift</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>decades</span> <span style=''>However</span> <span style=''>they</span> <span style=''>do</span> <span style=''>not</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>concept</span> <span style=''>drift</span> <span style=''>types</span> <span style=''>(eg</span> <span style=''>gradual</span> <span style=''>or</span> <span style=''>abrupt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>or</span> <span style=''>irregular)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>data</span> <span style=''>stream</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>(eg</span> <span style=''>balanced</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>labels)</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>can</span> <span style=''>detect</span> <span style=''>and</span> <span style=''>also</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>the</span> <span style=''>various</span> <span style=''>concept</span> <span style=''>drift</span> <span style=''>types</span> <span style=''>even</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='backgroun ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06478167501789549)
# 	challenging (0.09735146743020759)
# 	architecture (0.08589835361488905)
# 	knowledge (0.1327845382963493)
# 	processing (0.1070150322118826)
# 	detection (0.11954187544738726)
# 	different (0.26449534717251255)
# 	information (0.26521116678596995)
# 	recognition (0.12383679312813171)
# 	convolutional (0.13994273443092342)
#
# Some Statistics words are:
# 	algorithm (0.37587238285144564)
# 	stochastic (0.1345962113659023)
# 	estimation (0.16650049850448653)
# 	variables (0.13758723828514458)
# 	statistical (0.15054835493519442)
# 	theoretical (0.1580259222333001)
# 	distribution (0.18693918245264207)
# 	inference (0.20139581256231306)
# 	dimensional (0.19192422731804587)
# 	regression (0.17796610169491525)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="011f481b-5b52-42e1-bbed-3adf22c51255" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("011f481b-5b52-42e1-bbed-3adf22c51255")) {                    Plotly.newPlot(                        "011f481b-5b52-42e1-bbed-3adf22c51255",                        [{"x":["calculated","component","asymptotically","calculation","principal","engineering","calculate","algorithm","projection","estimation","evaluations","illustrations","reduction","direction","subspaces","generalize","containing","computation","sensitive","complexity","processing","components","dimension","dimensionality","optimization","searching","optimizes","embedding","riemannian","implementation","framework","superiority","competitors","demonstrates","stochastic","constraint","optimized","objective","addressed","expectation","solutions","functional","optimally","distribution","combinations","efficient","structured","multivariate","tomography","functionals","difficulty","estimated","fundamental","performance","improving","evaluation","comprehensive","combination","comparative","detection","maximally","rejecting","interesting","generalization","traditional","utilizing","represent","progressions","diversity","parameter","experiments","character","automatic","controlling","relationships","introduce","composition","documents","perspectives","designing","programming","computing","evolutionary","emphasize","researchers","advantage","computers","algorithms","application","important","henceforth","parallelism","representations","theoretical","considered","techniques","operators","including","chromosomes","randomness","information","dimensional","significant","simulation","enhancement","mechanisms","hyperacuity","dominance","biological","redundant","demonstration","environment","probabilistic","characteristics","advantages","heuristic","architecture","movements","specifies","binocular","correction","artificial","measurements","processes","redundancy","approaching","architectural","structural","representation","precision","filtering","annotations","clustering","challenging","classifying","segmentation","supervised","intermediate","significantly","localization","classification","recognition","curriculum","predictions","collected","instances","incorporate","counterparts","competitive","depending","translation","permutations","polynomial","synchronous","strategies","nonterminal","permutation","answering","interactively","conversation","understanding","extraction","interactive","motivated","introductory","collection","approaches","development","attention","expensive","illustrate","satisfies","consequences","condition","association","threefold","sufficient","necessary","formulates","equivalent","continuous","equivalence","practical","determining","establish","mathematical","metaheuristic","knowledge","combinatorial","similarity","disambiguation","relatedness","selection","exponential","estimates","simplification","applications","disambiguate","neighbors","distributional","retrieval","supervision","dictionary","conventional","exhibited","summarizes","assembling","incorrect","visualize","interactions","transferring","activation","functions","inference","conditional","decentralized","alleviates","localized","simultaneously","structure","graphical","outperforms","baselines","dependency","distributions","approximation","distributed","variational","empirical","extending","deficiency","pseudoinverse","resulting","contribute","particularly","regularization","factorization","substantially","interference","acquisition","coexistence","management","transmissions","identification","convolutional","overlapping","bandwidth","utilization","extensive","frequency","essential","snapshots","deterministic","mitigation"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unforeseen
# 	downweighting
# 	centering
# 	nontrivially
# 	operationally
# 	tractography
# 	refitting
# 	submatrix
# 	misspecified
# 	ancestral
# 	oftentimes
# 	exemplary
# 	assimilation
# 	exemplifies
# 	nonlinearly
# 	gribonval
# 	inversions
# 	combinatorially
# 	administrative
# 	missingness
# Some words which never appear in Statistics papers:
# 	henceforth
# 	chromosomes
# 	hyperacuity
# 	binocular
# 	curriculum
# 	nonterminal
# 	introductory
# 	threefold
# 	metaheuristic
# 	disambiguate
# 	assembling
# 	pseudoinverse
# 	coexistence
# 	transmissions
# 	misinformation
# 	credibility
# 	objectivity
# 	trustworthy
# 	predicates
# 	syntactical

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.07635513443672e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
